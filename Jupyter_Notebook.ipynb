# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM watson Studio

# %% [markdown]
# **Chenesai Nyakunu**
#   Data Scientist/Engineer

# %% [markdown]
# *I am interested in Data Science because I find it so fascinating and practical to draw business insights from data analysis which involves the entire process of structuring data, processing data, storing data and mning the data.*

# %% [markdown]
# ### My code in cell 5 must fine the sum of 10 and 15

# %%
10 + 15
# Out:
# 25

# %% [markdown]
# |Shoe Brand|Pairs available|
# |----|----|
# |Nike| 15|
# |Adidas|20|
#
#
# [Facebook](https://www.facebook.com/)
#
# ~Data Science is the sexiest job~
#
# * Pandas
# * NumPy
# * Python
#
#
#
#
#
# ![4525CFF8-B0C8-4DE9-8143-D897FFD7C52D.jpeg](attachment:a95a1ddf-7f9c-4566-8a73-0699613a5f8a.jpeg)
#
#
#
# `Lets highlight this`
#
#
#
#     code block
